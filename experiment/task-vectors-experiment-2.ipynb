# %% [markdown]
# # Installation and Imports

# %%
# !pip install git+https://github.com/openai/CLIP.git --quiet
# !pip install timm ftfy regex tqdm
# Out:
#   Preparing metadata (setup.py) ... done
# ...

# %%
import os
import sys

# Clone the official repo
# !git clone https://github.com/rajshreeee/task_vectors.git
os.chdir('/kaggle/working/task_vectors')

# Add to path
sys.path.insert(0, '/kaggle/working/task_vectors/src')

print("✅ Repository cloned and ready!")
# Out:
# Cloning into 'task_vectors'...
# remote: Enumerating objects: 80, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 80 (delta 36), reused 32 (delta 21), pack-reused 19 (from 1)
# Receiving objects: 100% (80/80), 112.32 KiB | 3.87 MiB/s, done.
# Resolving deltas: 100% (36/36), done.
# ✅ Repository cloned and ready!

# %% [markdown]
# ## Pull changes from git

# %%
import os
os.chdir('/kaggle/working/task_vectors')

# Pull your changes
# !git pull origin main --rebase

print("✅ Changes pulled!")

# %%
# !pip install open_clip_torch pandas openpyxl scikit-learn -q

# %%
import sys
sys.path.insert(0, '/kaggle/working/task_vectors')

# %%
cd /kaggle/working/task_vectors/src
# Out:
# /kaggle/working/task_vectors/src

# %%
from src.args import parse_arguments
from src.finetune import finetune

# Fine-tune on IMBALANCED version (BI-RADS 4 is minority with 200 samples)
class ArgsImbalanced:
    data_location = '/kaggle/input/miniddsm2'
    train_dataset = 'BIRADSImbalanced'  # Imbalanced version
    eval_datasets = ['BIRADSImbalanced']
    model = 'ViT-B-32'
    batch_size = 16
    lr = 1e-5
    wd = 0.1
    ls = 0.0
    warmup_length = 100
    epochs = 1
    save = '/kaggle/working/checkpoints/ViT-B-32/imbalanced'
    cache_dir = None
    openclip_cachedir = '/kaggle/working/.cache/open_clip'
    device = 'cuda'
    load = None
    results_db = '/kaggle/working/results_imbalanced.jsonl'
    exp_name = 'birads_imbalanced'

args_imbalanced = ArgsImbalanced()
zs_path_imbalanced, ft_path_imbalanced = finetune(args_imbalanced)

print("\n" + "="*70)
print("IMBALANCED VERSION COMPLETE")
print("="*70)
# Out:
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# ...
